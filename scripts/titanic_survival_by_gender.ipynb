# %%
"""
نرخ بقا در تایتانیک بر اساس جنسیت
"""

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import arabic_reshaper
from bidi.algorithm import get_display

def fix_farsi(text):
    return get_display(arabic_reshaper.reshape(text))

# دیتاست
titanic = sns.load_dataset("titanic")
data = titanic[["sex", "survived"]]

# محاسبه میانگین نرخ بقا برای هر جنسیت
survival_rate = data.groupby("sex")["survived"].mean().reset_index()

# رسم نمودار
sns.barplot(
    data=survival_rate,
    x="sex",
    y="survived",
    palette="Set2"
)

plt.title(fix_farsi("نرخ بقا در تایتانیک بر اساس جنسیت 🚢"), fontsize=14)
plt.ylabel(fix_farsi("نرخ بقا"))
plt.xlabel(fix_farsi("جنسیت"))
plt.ylim(0, 1)
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.savefig("../outputs/titanic_gender_survival.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# C:\Users\Tayebe\AppData\Local\Temp\ipykernel_2120\3260097660.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Tayebe\AppData\Local\Temp\ipykernel_2120\3260097660.py:35: UserWarning: Glyph 128674 (\N{SHIP}) missing from font(s) DejaVu Sans.
#   plt.savefig("../outputs/titanic_gender_survival.png", dpi=300, bbox_inches="tight")
# c:\Users\Tayebe\works\learning_skills\portfolio-analytics\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128674 (\N{SHIP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
